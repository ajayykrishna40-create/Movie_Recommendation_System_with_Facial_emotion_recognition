# %%
pip install opencv-python-headless keras h5py tensorflow pandas numpy
# Out:
# Requirement already satisfied: opencv-python-headless in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: keras in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.13.2)
# Requirement already satisfied: h5py in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.15.1)
# Requirement already satisfied: tensorflow in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.20.0)
# Collecting pandas
#   Using cached pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (2.4.2)
# Requirement already satisfied: absl-py in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from keras) (2.4.0)
# Requirement already satisfied: rich in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from keras) (14.3.3)
# Requirement already satisfied: namex in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from keras) (0.19.0)
# Requirement already satisfied: ml-dtypes in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in C:\Users\AJAY KRISHNA PVS\AppData\Roaming\Python\Python311\site-packages (from keras) (26.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in C:\Users\AJAY KRISHNA PVS\AppData\Roaming\Python\Python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\AJAY KRISHNA PVS\AppData\Roaming\Python\Python311\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\AJAY KRISHNA PVS\AppData\Roaming\Python\Python311\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\AJAY KRISHNA PVS\AppData\Roaming\Python\Python311\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\AJAY KRISHNA PVS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --------------- ------------------------ 3.9/9.9 MB 21.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 19.3 MB/s  0:00:00
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-3.0.1 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
model_path = "E:\\Movie_recommendation\\FER_model (1).h5"
if os.path.exists(model_path):
    print("Model file exists.")
else:
    print("Model file does not exist.")
# Out:
# Model file exists.

# %%
import os
from keras.models import load_model
import cv2
import pandas as pd
import random
import numpy as np
import cv2
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# Path to the model file (assumes the file is already present in the working directory)
model_path = "E:\\Movie_recommendation\\FER_model (1).h5"

# Load the facial expression model
if os.path.exists(model_path):
    model = load_model(model_path)
    print("Model loaded successfully.")
else:
    raise FileNotFoundError(f"Model file does not exist at {model_path}")

# Define the facial expression labels
expression_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Function to capture and decode an image from JavaScript
def js_to_image(js_reply):
    """
    Converts the JavaScript object to an OpenCV image.
    """
    image_bytes = b64decode(js_reply.split(',')[1])
    jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
    img = cv2.imdecode(jpg_as_np, flags=1)
    return img

# JavaScript to take a photo from the webcam
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});
      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await new Promise((resolve) => (video.onloadedmetadata = resolve));
      video.play();

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getTracks().forEach((track) => track.stop());
      div.remove();

      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    return data

# Capture a photo
img_str = take_photo()
img = js_to_image(img_str)

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces in the frame
faces = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml').detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Initialize the emotion variable
emotion = None

# Loop through each face
for (x, y, w, h) in faces:
    # Extract the face from the frame
    face = gray[y:y+h, x:x+w]

    # Resize the face to the model's input size (48x48)
    face = cv2.resize(face, (48, 48))

    # Convert the face to a numpy array
    face = np.array(face).reshape(-1, 48, 48, 1)
    face = face / 255.0

    # Make predictions using the model
    predictions = model.predict(face, verbose=0)

    # Get the index of the highest prediction
    index = np.argmax(predictions)

    # Get the corresponding emotion label
    emotion = expression_labels[index]

    # Draw the bounding box and label on the frame
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    cv2.putText(img, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Break the loop after processing the first face
    break

# Display the frame
cv2.imshow("Frame", frame)
cv2.waitKey(1)
print(emotion)

emotion_to_genres = {
    'Happy': ['Comedy', 'Adventure', 'Fantasy', 'Musical'],
    'Sad': ['Comedy', 'Family', 'Fantasy', 'Animation'],
    'Angry': ['Action', 'Thriller', 'Crime'],
    'Fear': ['Horror', 'Thriller', 'Mystery'],
    'Neutral': ['Drama', 'Documentary', 'History'],
    'Disgust': ['Comedy', 'Fantasy'],
    'Surprise': ['Mystery', 'Fantasy', 'Science Fiction']
}

# Initialize an empty dictionary to store movie titles for each emotion
emotion_movies = {label: [] for label in expression_labels}

# Read the CSV file
try:
    df = pd.read_csv("movierecom.csv", encoding='ISO-8859-1')
except UnicodeDecodeError:
    # If it fails, try with UTF-16 encoding
    df = pd.read_csv("movierecom.csv", encoding='utf-16')

# Iterate through each row in the dataframe
for index, row in df.iterrows():
    movie_title = row['Movie_Title']
    movie_genre = row['Movie_Genre']

    # Ensure movie_genre is a string and handle NaN values
    if isinstance(movie_genre, str):
        # Check if movie_genre matches any genres associated with the emotions
        for emotion_label, genres in emotion_to_genres.items():
            for genre in genres:
                if genre.strip().lower() in movie_genre.lower():
                    emotion_movies[emotion_label].append(movie_title)
                    break  # Avoid adding the same movie multiple times for the same emotion

# Function to suggest a random movie based on emotion
def suggest_movie(emotion):
    if emotion in emotion_movies:
        movies_for_emotion = emotion_movies[emotion]
        if movies_for_emotion:
            return random.choice(movies_for_emotion)
        else:
            return "No movies found for this emotion."
    else:
        return "Invalid emotion."

# Suggest a movie based on the detected emotion
suggested_movie = suggest_movie(emotion)
print(f"For emotion '{emotion}', suggested movie: {suggested_movie}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 7
#       5 import random
#       6 import numpy as np
# ----> 7 from google.colab.patches import cv2_imshow
#       8 from IPython.display import display, Javascript
#       9 from google.colab.output import eval_js
#
# ModuleNotFoundError: No module named 'google.colab'
